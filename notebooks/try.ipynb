# %%
import h5py
h5_file = "../data/raw/ukdale.h5"

# %%
with h5py.File(h5_file, "r") as store:
    df = store["/building4/elec/meter1/table"]
    print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 with h5py.File(h5_file, "r") as store:
#       2     df = store["/building4/elec/meter1/table"]
# ----> 3     print(df.head())
#
# AttributeError: 'Dataset' object has no attribute 'head'

# %%
import pandas as pd

df = pd.read_hdf("../data/raw/ukdale.h5", "/building4/elec/meter1/table")
print(df.head())
print(df.columns)
# Out:
#                  index  values_block_0
# 0  1362840007000000000           637.0
# 1  1362840013000000000           625.0
# 2  1362840019000000000           625.0
# 3  1362840025000000000           622.0
# 4  1362840032000000000           641.0
# Index(['index', 'values_block_0'], dtype='object')
